# %%
from langchain_core.documents import Document

# %%
sample_text ={
    "../data/text_files/python_intro.txt": """Python is a high-level, interpreted programming language that is widely used for web development, data analysis, artificial intelligence, and scientific computing. It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes code readability and simplicity, making it an excellent choice for beginners and experienced programmers alike. The language supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python has a large standard library and a
     vibrant ecosystem of third-party packages, which makes it a versatile tool for a wide range of applications.
     python is known for its easy-to-learn syntax, which allows developers to write clear and concise code. It is also an open-source language, which means that it is freely available for anyone to use and modify. Python's popularity has grown significantly in recent years, making it one of the most widely used programming languages in the world.
     good for data science and machine learning, web development, automation, and more. With its extensive libraries and frameworks, Python continues to be a powerful tool for developers across various industries.
     anyone can learn Python, and it is often recommended as a first programming language due to its simplicity and versatility. Whether you are interested in web development, data analysis, or artificial intelligence, Python provides the tools and resources to help you achieve your goals.""",
    "../data/text_files/data_science.txt": """Data science is an interdisciplinary field that combines
      """,
    "../data/text_files/machine_learning.txt": """Machine learning is a subset of artificial intelligence that focuses on the development of algorithms and statistical models that enable computers to perform tasks without explicit programming. It involves training models on data to make predictions or decisions. Machine learning has various applications, including image recognition, natural language processing, and autonomous vehicles.
     The field of machine learning is rapidly evolving, with new techniques and algorithms being developed regularly. It has become an essential tool for businesses and researchers alike, as it allows for the analysis of large datasets and the extraction of valuable insights. As machine learning continues to advance, it is expected to play an increasingly significant role in shaping the future of technology and society.
     anyone interested in machine learning can start by learning the basics of programming and statistics, and then gradually move on to more advanced topics such as deep learning and reinforcement learning. With the right resources and dedication, anyone can become proficient in machine learning and contribute to this exciting field.
     machine learning is a powerful tool that has the potential to revolutionize various industries, from healthcare to finance. As the field continues to grow, it is important for individuals and organizations to stay informed about the latest developments and best practices in machine learning to harness its full potential.
     good for data science and artificial intelligence, machine learning is a rapidly evolving field that offers numerous opportunities for innovation and discovery. With its ability to analyze large datasets and make predictions, machine learning is transforming the way we approach problems and make decisions in various domains.""",

}

import os

for file_path, content in sample_text.items():
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding='utf-8')
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python is a high-level, interpreted programming language that is widely used for web development, data analysis, artificial intelligence, and scientific computing. It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes code readability and simplicity, making it an excellent choice for beginners and experienced programmers alike. The language supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python has a large standard library and a\n     vibrant ecosystem of third-party packages, which makes it a versatile tool for a wide range of applications.\n     python is known for its easy-to-learn syntax, which allows developers to write clear and concise code. It is also an open-source language, which means that it is freely available for anyone to use and modify. Python's popularity has grown significantly 
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader


directory_loader = DirectoryLoader("../data/text_files", 
                                    glob="*.txt",
                                    loader_cls=TextLoader, 
                                    loader_kwargs={'encoding': 'utf-8'}, 
                                    show_progress=False)
documents = directory_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\data_science.txt'}, page_content='Data science is an interdisciplinary field that combines\n      '),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

directory_loader = DirectoryLoader("../data/pdf", 
                                    glob="*.pdf",
                                    loader_cls=PyPDFLoader, 
                                    show_progress=False)
pdf_documents = directory_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-22T15:28:51+00:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-22T15:28:51+00:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023/Debian) kpathsea version 6.3.5', 'source': '..\\data\\pdf\\vivek_resume L.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Vivek Jeevanaraj\n+33 695 910 077 | vivekjeevanaraj@gmail.com | linkedin.com/in/vivekjeevanaraj | vivekinfor.netlify.app\nProfessional Summary\nFull-Stack Software Engineer with 4+ years of experience building scalable, high-performance applications across the entire\nstack. Expert in backend development with Java and Spring Boot, designing robust APIs and microservices, combined with\nstrong frontend expertise in React and Angular. Proven track record optimizing systems for low-latency performance,\nleading cross-func
# ...
